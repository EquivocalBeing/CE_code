# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import gridspec

data = pd.read_csv(
    r"C:\Users\cacam\OneDrive\Documents\ME348_python_project\proj_4_10_25_nd_rocket\sol_eigenvalues.txt",
                   delimiter='\s+') 
#print(data.head())
data.columns = ["num", "Xi", "eigen_1", 'eigen_1_imagery', 'eigen_2', 'eigen_2_imagery', 'eigen_3', 'eigen_3_imagery',
                'eigen_4', 'eigen_4_imagery', 'eigen_5', 'eigen_5_imagery', 'eigen_6', 'eigen_6_imagery']


xi = data["Xi"]
e1 = data["eigen_1"]
e1_i = data["eigen_1_imagery"]
e2 = data["eigen_2"]
e2_i = data["eigen_2_imagery"]
e3 = data["eigen_3"]
e3_i = data["eigen_3_imagery"]
e4 = data["eigen_4"]
e4_i = data["eigen_4_imagery"]
e5 = data["eigen_5"]
e5_i = data["eigen_5_imagery"]
e6 = data["eigen_6"]
e6_i = data["eigen_6_imagery"]


################################################################################################################################


plt.figure(1, figsize = (19, 8))

plt.yticks(fontsize = 20, fontweight = "bold")
plt.xticks(fontsize = 20, fontweight = "bold")
plt.grid(True, which="both", ls="-")

plt.scatter(xi, e1, color = "blue", label = "Eigen 1")
plt.scatter(xi, e2, color = "gold", label = "Eigen 2")
plt.scatter(xi, e3, color = "red", label = "Eigen 3")
plt.scatter(xi, e4, color = "green", label = "Eigen 4")
plt.scatter(xi, e5, color = "lime", label = "Eigen 5")
plt.scatter(xi, e6, color = "purple", label = "Eigen 6")

plt.title("Real Eigen Values vs Xi", fontweight = 'bold', fontsize = 25)
plt.ylabel("Eigen Values", fontweight = "bold", fontsize = 20)
plt.xlabel("Xi", fontweight = "bold", fontsize = 20)
plt.legend(loc = "lower left", fontsize = 16, ncol = 2)
plt.xticks(np.arange(round(min(xi)), round(max(xi))+0.1, 0.1), rotation = -40)
plt.xlim(0,3.01)
plt.ylim(-2, 0.1)
#plt.show()
plt.savefig("me348_hw_13_eigen_real_2.png", bbox_inches='tight')

################################################################################################################################


plt.figure(2, figsize = (19, 8))

plt.yticks(fontsize = 20, fontweight = "bold")
plt.xticks(fontsize = 18, fontweight = "bold")
plt.grid(True, which="both", ls="-")

plt.scatter(xi, e1_i, color = "blue", label = "Eigen 1")
plt.scatter(xi, e2_i, color = "gold", label = "Eigen 2")
plt.scatter(xi, e3_i, color = "red", label = "Eigen 3")
plt.scatter(xi, e4_i, color = "green", label = "Eigen 4")
plt.scatter(xi, e5_i, color = "lime", label = "Eigen 5")
plt.scatter(xi, e6_i, color = "purple", label = "Eigen 6")

plt.title("Imaginary Eigen Values vs Xi", fontweight = 'bold', fontsize = 25)
plt.ylabel("Eigen Values", fontweight = "bold", fontsize = 20)
plt.xlabel("Xi", fontweight = "bold", fontsize = 20)
plt.legend(loc = "lower right", fontsize = 16, ncol = 2)
plt.xticks(np.arange(round(min(xi)), round(max(xi))+0.1, 0.1), rotation = -50)
plt.xlim(0,3)
#plt.ylim(-0.0001,0.0001)
#plt.show()
plt.savefig("me348_hw_13_eigen_imaginary_2.png", bbox_inches='tight')

# %%
#--------------------------------------------------------- Input --------------------------------------------------------------#
xi = 1.0
#------------------------------------------------------------------------------------------------------------------------------#

m = 2965000   # kg
L = 111       # m
T_h = 1.186
k_tld = 0.25
g_tld = 1
g = 9.81      # m/s^2
kx_kq = 0.5
cx_cq = 0.5


################################################################################################################################

Ig = (m * L**2) / 12
T = np.sqrt( (g_tld * L) / g )
k_x = (k_tld * m) / T**2
c_x = xi * ( 2 * np.sqrt(k_x * m) )
T_m_tld = (T_h * T**2) / (m * L) 
k_q = kx_kq * k_x
c_q = cx_cq * c_x

################################################################################################################################


print("----------------------")
print(f"k_x:    {k_x:.4f} N/m")
print(f"k_q:    {k_q:.4f} [?]")
print(f"c_x:    {c_x:.4f} N/m")
print(f"c_q:    {c_q:.4f} [?]")
print("----------------------")
# Out:
# ----------------------
# k_x:    65510.4730 N/M
# k_q:    32755.2365 [?]
# c_x:    881450.0607 N/M
# c_q:    440725.0303 [?]
# ----------------------

# %%
data = pd.read_csv(
    r"C:\Users\cacam\OneDrive\Documents\ME348_python_project\proj_4_10_25_nd_rocket\solution.txt",
                   delimiter='\s+') 
#print(data.head())
data.columns = ["time_nd", "x_nd", "v_x_nd", "y_nd", "v_y_nd","theta_nd", "omega_nd", "m1_dx/dt_nd", "m1_dv/dt_nd", 
                "m2_dx/dt_nd", "m2_dv/dt_nd","theta_dt_nd", "omega_dt_nd"]

time_nd = data["time_nd"]
x_nd = data["x_nd"]
v_x_nd = data["v_x_nd"]
y_nd = data["y_nd"]
v_y_nd = data["v_y_nd"]
theta_nd = data["theta_nd"]
omega_nd = data["omega_nd"]


################################################################################################################################


fig = plt.figure(1, figsize = (40,20))
gs = gridspec.GridSpec(2,3, height_ratios = [1,1], hspace = 0.2, wspace = 0.4)

fig.suptitle("Non-Dimensional", fontweight = 'bold', fontsize = 30, va = "center", y = .93)

axis1 = fig.add_subplot(gs[0,0])
axis1.tick_params(labelsize=22)
axis1.yaxis.get_offset_text().set_fontsize(18)

axis1.scatter(time_nd, x_nd, color = "blue", linewidth = 3)

axis1.set_title("x_nd", fontweight = 'bold', fontsize = 25)
axis1.set_xlabel("Time", fontweight = "bold", fontsize = 20)
axis1.set_ylabel("Displacement", fontweight = "bold", fontsize = 20)
#axis1.set_ylim(1,-1)
axis1.grid(True, which="both", ls="-")

#------------------------------------------------------------------------------------------------------------------------------#

axis2 = fig.add_subplot(gs[0,1])
axis2.tick_params(labelsize=22)
axis2.yaxis.get_offset_text().set_fontsize(18)

axis2.scatter(time_nd, v_x_nd, color = "red", linewidth = 3)

axis2.set_title("v_x_nd", fontweight = 'bold', fontsize = 25)
axis2.set_xlabel("Time", fontweight = "bold", fontsize = 20)
axis2.set_ylabel("Velocity", fontweight = "bold", fontsize = 20)
#axis2.set_ylim(1,-1)
axis2.grid(True, which="both", ls="-")

#------------------------------------------------------------------------------------------------------------------------------#

axis3 = fig.add_subplot(gs[1,0])
axis3.tick_params(labelsize=22)


axis3.scatter(time_nd, y_nd, color = "blue", linewidth = 3)

axis3.set_title("y_nd", fontweight = 'bold', fontsize = 25)
axis3.set_xlabel("Time", fontweight = "bold", fontsize = 20)
axis3.set_ylabel("Displacement", fontweight = "bold", fontsize = 20)
axis3.grid(True, which="both", ls="-")

#------------------------------------------------------------------------------------------------------------------------------#

axis4 = fig.add_subplot(gs[1,1])
axis4.tick_params(labelsize=22)

axis4.scatter(time_nd, v_y_nd, color = "red", linewidth = 3)

axis4.set_title("v_y_nd", fontweight = 'bold', fontsize = 25)
axis4.set_xlabel("Time", fontweight = "bold", fontsize = 20)
axis4.set_ylabel("Velocity", fontweight = "bold", fontsize = 20)
axis4.grid(True, which="both", ls="-")

#------------------------------------------------------------------------------------------------------------------------------#

axis5 = fig.add_subplot(gs[0,2])
axis5.tick_params(labelsize=22)

axis5.scatter(time_nd, theta_nd, color = "red", linewidth = 3)

axis5.set_title("theta_nd", fontweight = 'bold', fontsize = 25)
axis5.set_xlabel("Time", fontweight = "bold", fontsize = 20)
axis5.set_ylabel("Angle", fontweight = "bold", fontsize = 20)
axis5.grid(True, which="both", ls="-")

#------------------------------------------------------------------------------------------------------------------------------#

axis6 = fig.add_subplot(gs[1,2])
axis6.tick_params(labelsize=22)

axis6.scatter(time_nd, omega_nd, color = "red", linewidth = 3)

axis6.set_title("omega_nd", fontweight = 'bold', fontsize = 25)
axis6.set_xlabel("Time", fontweight = "bold", fontsize = 20)
axis6.set_ylabel("Angular Velocity", fontweight = "bold", fontsize = 20)
axis6.grid(True, which="both", ls="-")

plt.savefig("ME_348_HW_13_nd_zero.png", bbox_inches='tight')
